# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# # Extracting features of 2022 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\ncs\AppData\Local\Temp\ipykernel_4404\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                     Title  \
# 0      J A N U A R Y        7.0                   The 355
# 1      J A N U A R Y        7.0  The Legend of La Llorona
# 2      J A N U A R Y        7.0              The Commando
# 3      J A N U A R Y        7.0            American Siege
# 4      J A N U A R Y       14.0                    Scream
# ..               ...        ...                       ...
# 320  D E C E M B E R       30.0            Alice, Darling
# 321  D E C E M B E R        NaN                       NaN
# 322  D E C E M B E R        NaN                       NaN
# 323  D E C E M B E R        NaN                       NaN
# 324  D E C E M B E R        NaN                       NaN
#
#                                     Production company  \
# 0    Universal Pictures / Freckle Films / FilmNatio...
# 1                                          Saban Films
# 2                                          Saban Films
# 3                               Vertical Entertainment
# 4            Paramount Pictures / Spyglass Media Group
# ..                                                 ...
# 320                     Lionsgate / Elevation Pictures
# 321                                                NaN
# 322                                                NaN
# 323                                                NaN
# 324                                                NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 320  Mary Nighy (director); Alanna Francis (screenp...
# 321                                                NaN
# 322                                                NaN
# 323                                                NaN
# 324                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 320                                                NaN
# 321                                                NaN
# 322                                                NaN
# 323                                                NaN
# 324                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 320  [261]
# 321    NaN
# 322    NaN
# 323    NaN
# 324    NaN
#
# [325 rows x 7 columns]

# %%
df_2022 = df[['Title','Cast and crew']]

# %%
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 320            Alice, Darling
# 321                       NaN
# 322                       NaN
# 323                       NaN
# 324                       NaN
#
#                                          Cast and crew
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 320  Mary Nighy (director); Alanna Francis (screenp...
# 321                                                NaN
# 322                                                NaN
# 323                                                NaN
# 324                                                NaN
#
# [325 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '440945e71e455226b9f8cb03f967e669'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\ncs\AppData\Local\Temp\ipykernel_4404\2369738557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 320            Alice, Darling
# 321                       NaN
# 322                       NaN
# 323                       NaN
# 324                       NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 320  Mary Nighy (director); Alanna Francis (screenp...
# 321                                                NaN
# 322                                                NaN
# 323                                                NaN
# 324                                                NaN
#
#                           genres
# 0                Action Thriller
# 1       Family Animation Fantasy
# 2          Action Crime Thriller
# 3    Action Thriller Crime Drama
# 4        Horror Mystery Thriller
# ..                           ...
# 320               Thriller Drama
# 321                       Comedy
# 322                       Comedy
# 323                       Comedy
# 324                       Comedy
#
# [325 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\ncs\AppData\Local\Temp\ipykernel_4404\3796821595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\ncs\AppData\Local\Temp\ipykernel_4404\2929607607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\ncs\AppData\Local\Temp\ipykernel_4404\2384233428.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 320            Alice, Darling
# 321                       NaN
# 322                       NaN
# 323                       NaN
# 324                       NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 320  Mary Nighy (director); Alanna Francis (screenp...
# 321                                                NaN
# 322                                                NaN
# 323                                                NaN
# 324                                                NaN
#
#                           genres                         director_name  \
# 0                Action Thriller                         Simon Kinberg
# 1       Family Animation Fantasy                Patricia Harris Seeley
# 2          Action Crime Thriller                            Asif Akbar
# 3    Action Thriller Crime Drama                          Edward Drake
# 4        Horror Mystery Thriller  Matt Bettinelli-Olpin, Tyler Gillett
# ..                           ...                                   ...
# 320               Thriller Drama                            Mary Nighy
# 321                       Comedy                                   nan
# 322                       Comedy                                   nan
# 323                       Comedy                                   nan
# 324                       Comedy                                   nan
#
#           actor_1_name       actor_2_name     actor_3_name
# 0     Jessica Chastain     Lupita Nyong'o    Penélope Cruz
# 1        Autumn Reeser       Antonio Cupo      Danny Trejo
# 2        Mickey Rourke  Michael Jai White              NaN
# 3    Timothy V. Murphy       Bruce Willis              NaN
# 4      Melissa Barrera      Mason Gooding     Jenna Ortega
# ..                 ...                ...              ...
# 320      Anna Kendrick    Kaniehtiio Horn  Charlie Carrick
# 321                nan                NaN              NaN
# 322                nan                NaN              NaN
# 323                nan                NaN              NaN
# 324                nan                NaN              NaN
#
# [325 rows x 7 columns]

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df22
# Out:
#                             director_name       actor_1_name  \
# 0                           Simon Kinberg   Jessica Chastain
# 1                  Patricia Harris Seeley      Autumn Reeser
# 2                              Asif Akbar      Mickey Rourke
# 3                            Edward Drake  Timothy V. Murphy
# 4    Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera
# ..                                    ...                ...
# 320                            Mary Nighy      Anna Kendrick
# 321                                   nan                nan
# 322                                   nan                nan
# 323                                   nan                nan
# 324                                   nan                nan
#
#           actor_2_name     actor_3_name                       genres  \
# 0       Lupita Nyong'o    Penélope Cruz              Action Thriller
# 1         Antonio Cupo      Danny Trejo     Family Animation Fantasy
# 2    Michael Jai White              NaN        Action Crime Thriller
# 3         Bruce Willis              NaN  Action Thriller Crime Drama
# 4        Mason Gooding     Jenna Ortega      Horror Mystery Thriller
# ..                 ...              ...                          ...
# 320    Kaniehtiio Horn  Charlie Carrick               Thriller Drama
# 321                NaN              NaN                       Comedy
# 322                NaN              NaN                       Comedy
# 323                NaN              NaN                       Comedy
# 324                NaN              NaN                       Comedy
#
#                   movie_title
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 320            Alice, Darling
# 321                       NaN
# 322                       NaN
# 323                       NaN
# 324                       NaN
#
# [325 rows x 6 columns]

# %%
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df22['actor_2_name'] + ' '+ new_df22['actor_3_name'] + ' '+ new_df22['director_name']

# %%
new_df22.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name     11
# actor_3_name     35
# genres            2
# movie_title       4
# comb             35
# dtype: int64

# %%
new_df22 = new_df22.dropna(how='any')

# %%
new_df22.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()
# Out:
# C:\Users\ncs\AppData\Local\Temp\ipykernel_4404\2732328091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22
# Out:
#                             director_name      actor_1_name     actor_2_name  \
# 0                           Simon Kinberg  Jessica Chastain   Lupita Nyong'o
# 1                  Patricia Harris Seeley     Autumn Reeser     Antonio Cupo
# 4    Matt Bettinelli-Olpin, Tyler Gillett   Melissa Barrera    Mason Gooding
# 5           Jennifer Kluska, Derek Drymon      Andy Samberg     Selena Gomez
# 6                             Luis Prieto  Cameron Monaghan     Frank Grillo
# ..                                    ...               ...              ...
# 316                       Damien Chazelle         Brad Pitt    Margot Robbie
# 317                          Scott Cooper    Christian Bale    Harry Melling
# 318                          Marc Forster         Tom Hanks  Mariana Treviño
# 319                           Juel Taylor       John Boyega   Teyonah Parris
# 320                            Mary Nighy     Anna Kendrick  Kaniehtiio Horn
#
#           actor_3_name                                     genres  \
# 0        Penélope Cruz                            Action Thriller
# 1          Danny Trejo                   Family Animation Fantasy
# 4         Jenna Ortega                    Horror Mystery Thriller
# 5         Kathryn Hahn  Animation Comedy Family Fantasy Adventure
# 6           Lilly Krug                                   Thriller
# ..                 ...                                        ...
# 316        Diego Calva  Action Adventure Science Fiction Thriller
# 317   Gillian Anderson              Crime Thriller Mystery Horror
# 318      Rachel Keller                               Drama Comedy
# 319  Kiefer Sutherland             Science Fiction Comedy Mystery
# 320    Charlie Carrick                             Thriller Drama
#
#                            movie_title  \
# 0                              the 355
# 1             the legend of la llorona
# 4                               scream
# 5    hotel transylvania: transformania
# 6                            shattered
# ..                                 ...
# 316                            babylon
# 317                  the pale blue eye
# 318                  a man called otto
# 319                 they cloned tyrone
# 320                     alice, darling
#
#                                                   comb
# 0    Jessica Chastain Lupita Nyong'o Penélope Cruz ...
# 1    Autumn Reeser Antonio Cupo Danny Trejo Patrici...
# 4    Melissa Barrera Mason Gooding Jenna Ortega Mat...
# 5    Andy Samberg Selena Gomez Kathryn Hahn Jennife...
# 6    Cameron Monaghan Frank Grillo Lilly Krug Luis ...
# ..                                                 ...
# 316  Brad Pitt Margot Robbie Diego Calva Damien Cha...
# 317  Christian Bale Harry Melling Gillian Anderson ...
# 318  Tom Hanks Mariana Treviño Rachel Keller Marc F...
# 319  John Boyega Teyonah Parris Kiefer Sutherland J...
# 320  Anna Kendrick Kaniehtiio Horn Charlie Carrick ...
#
# [288 rows x 7 columns]

# %%
old_df = pd.read_csv('main2_data.csv')

# %%
old_df
# Out:
#                                           director_name  \
# 0                                         James Cameron
# 1                                        Gore Verbinski
# 2                                            Sam Mendes
# 3                                     Christopher Nolan
# 4                                           Doug Walker
# ...                                                 ...
# 6430                                     Matthew Vaughn
# 6431                                          Joel Coen
# 6432                                  Denzel Washington
# 6433                                     Erwin brothers
# 6434  Apichatpong Weerasethakul (director/acreenplay...
#
#                                            actor_1_name       actor_2_name  \
# 0                                           CCH Pounder   Joel David Moore
# 1                                           Johnny Depp      Orlando Bloom
# 2                                       Christoph Waltz       Rory Kinnear
# 3                                             Tom Hardy     Christian Bale
# 4                                           Doug Walker         Rob Walker
# ...                                                 ...                ...
# 6430                                      Ralph Fiennes     Gemma Arterton
# 6431                                  Denzel Washington  Frances McDormand
# 6432                                  Michael B. Jordan       Chanté Adams
# 6433                                       Zachary Levi        Anna Paquin
# 6434  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#               actor_3_name                                 genres  \
# 0                Wes Studi        Action|Adventure|Fantasy|Sci-Fi
# 1           Jack Davenport               Action|Adventure|Fantasy
# 2         Stephanie Sigman              Action|Adventure|Thriller
# 3     Joseph Gordon-Levitt                        Action|Thriller
# 4                  unknown                            Documentary
# ...                    ...                                    ...
# 6430            Rhys Ifans  Action Adventure Thriller War Mystery
# 6431         Bertie Carvel                              Drama War
# 6432       Jalon Christian                          Drama Romance
# 6433          Dennis Quaid                                  Drama
# 6434        Jeanne Balibar          Drama Science Fiction Mystery
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6430                                     the king's man
# 6431                             the tragedy of macbeth
# 6432                               a journal for jordan
# 6433                                  american underdog
# 6434                                            memoria
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6430  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 6431  Denzel Washington Frances McDormand Bertie Car...
# 6432  Michael B. Jordan Chanté Adams Jalon Christian...
# 6433  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 6434  Apichatpong Weerasethakul (director/acreenplay...
#
# [6435 rows x 7 columns]

# %%
final_df = old_df.append(new_df22,ignore_index=True)
# Out:
# C:\Users\ncs\AppData\Local\Temp\ipykernel_4404\1166909226.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(new_df22,ignore_index=True)

# %%
final_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6718    Damien Chazelle        Brad Pitt     Margot Robbie
# 6719       Scott Cooper   Christian Bale     Harry Melling
# 6720       Marc Forster        Tom Hanks   Mariana Treviño
# 6721        Juel Taylor      John Boyega    Teyonah Parris
# 6722         Mary Nighy    Anna Kendrick   Kaniehtiio Horn
#
#               actor_3_name                                     genres  \
# 0                Wes Studi            Action|Adventure|Fantasy|Sci-Fi
# 1           Jack Davenport                   Action|Adventure|Fantasy
# 2         Stephanie Sigman                  Action|Adventure|Thriller
# 3     Joseph Gordon-Levitt                            Action|Thriller
# 4                  unknown                                Documentary
# ...                    ...                                        ...
# 6718           Diego Calva  Action Adventure Science Fiction Thriller
# 6719      Gillian Anderson              Crime Thriller Mystery Horror
# 6720         Rachel Keller                               Drama Comedy
# 6721     Kiefer Sutherland             Science Fiction Comedy Mystery
# 6722       Charlie Carrick                             Thriller Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6718                                            babylon
# 6719                                  the pale blue eye
# 6720                                  a man called otto
# 6721                                 they cloned tyrone
# 6722                                     alice, darling
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6718  Brad Pitt Margot Robbie Diego Calva Damien Cha...
# 6719  Christian Bale Harry Melling Gillian Anderson ...
# 6720  Tom Hanks Mariana Treviño Rachel Keller Marc F...
# 6721  John Boyega Teyonah Parris Kiefer Sutherland J...
# 6722  Anna Kendrick Kaniehtiio Horn Charlie Carrick ...
#
# [6723 rows x 7 columns]

# %%
final_df.to_csv('main3_data.csv',index=False)
